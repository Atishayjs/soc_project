# %%
class friemds:
    gfcount = 1
    virgine = "samdlyyes"
    kiss = "yess"
    bj = "yess"
    def gf(self):
        print(f" gf's name is {self.gfname}")
    @staticmethod
    def greet():
      print("whats'ap bichh")

atishay=friemds()
vinayak=friemds()
sanket=friemds()
yash=friemds()
atishay.bff="nand"
atishay.gfname="shruti"
sanket.gfname="simran"

yash.gfcount=0


print(vinayak.virgine)
print(sanket.kiss)
print(atishay.bff)
atishay.gf()
sanket.gf()
yash.greet()
# Out:
# samdlyyes
# yess
# nand
#  gf's name is shruti
#  gf's name is simran
# whats'ap bichh

# %%
class friemds:
  gfcount=1
  def __init__(self,name,gfcount,gf):
    self.name=name
    self.gfcount= gfcount
    self.gf=gf
    print("some details about some ladies:")
  def details(self):
     print(f"name of the bitch is {self.name}, his gf count is {self.gfcount} and her name is {self.gf}")

sanket = friemds("sanket",2,"simran")


sanket.details()
# Out:
# some details about some ladies:
# name of the bitch is sanket, his gf count is 2 and her name is simran

# %% [markdown]
# practice *set* 10

# %%
class programmer:
  def __init__(self):
    print("hello")
  comapny= "microsoft" 
  salary= "1M"
  mgs= "married"
  def details(self):
    print(f"the employee is working in {self.comapny} . He is {self.mgs} . his wife name is {self.wife}. his salary is {self.salary}")

atishay = programmer()
shrey = programmer()
das = programmer()

atishay.wife="shruti"
shrey.wife="srishti"
das.wife="samriddhi :/"
das.wife=0
das.details()
# Out:
# hello
# hello
# hello
# the employee is working in microsoft . He is married . his wife name is 0. his salary is 1M

# %%
class calculator:
  def find(a,b):
    if b=="square":
      print(a*a)
    elif b=="cube":
      print(a*a*a)
    elif b=="sqrt":
      print(sqrt(b))

find(9,"sqrt")

# %%
class train:
  def __init__(self):
    print("Welcome to Indian Railways ")
  method= "offline" 
  status= "confirmed"
  no_of_seats= "2"
  fare=500
  def details(atishay):
          print(f"the employee booking method is  {atishay.method} . He/she ticket status is {atishay.status} . his/her no of seats  is/are {atishay.no_of_seats}. his fare is {atishay.fare}")

atishay=train()
nandini=train()
atishay.method="online"
atishay.status="waiting"
atishay.no_of_seats=1


atishay.details()
# Out:
# Welcome to Indian Railways
# Welcome to Indian Railways
# the employee booking method is  online . He/she ticket status is waiting . his/her no of seats  is/are 1. his fare is 500
